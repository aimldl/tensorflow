# %%
#pip install matplotlib --upgrade
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 256, endpoint=True)
#y = 1/(1 + np.exp(-x))
#z = np.square(y)
#z = np.square(1/(1 + np.exp(-x)))
z = np.square(-0.5 + 1/(1 + np.exp(-x)))

#plt.plot(x, y)
#plt.plot(y, z)
plt.plot(x, z)

plt.show()
