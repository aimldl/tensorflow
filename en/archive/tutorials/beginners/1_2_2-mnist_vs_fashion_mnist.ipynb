# %% [markdown]
# ##### aimldl >python3 > packages > tensorflow > tutorials > beginners > 1_2_2-mnist_vs_fashion_mnist.ipynb
#
# * This notebook is a summary of [1_1-beginner_quickstart.ipynb](#1_1-beginner_quickstart.ipynb) and [1_2_1-basic_image_classification.ipynb](#1_2_1-basic_image_classification.ipynb).
#
# # MNIST vs Fashion-MNIST
# The previous examples of the MNIST dataset and the Fashion MNIST dataset are quite similar because the Fashion MNIST is designed with the MNIST datset in mind. They are compared in [1_2_1-mnist_vs_fashion_mnist.xlsx](#1_2_1-mnist_vs_fashion_mnist.xlsx) and its screencapture is presented below.

# %% [markdown]
# ![1_2_2-mnist_vs_fashion_mnist.png](attachment:1_2_2-mnist_vs_fashion_mnist.png)

# %% [markdown]
# (EOF)
